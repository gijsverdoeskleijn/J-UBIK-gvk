# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/ubikEnv/bin/python

# %%
import jwst_demo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import jwst_demo
#
# ModuleNotFoundError: No module named 'jwst_demo'
